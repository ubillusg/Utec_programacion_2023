# %% [markdown]
# <a href="https://colab.research.google.com/github/ubillusg/Utec_programacion_2023/blob/main/modulo_2/4.%20Pandas_Dataframes_revisado_en_clase_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://www.ctic.uni.edu.pe/wp-content/uploads/2022/04/588px-x-348px-web-1.png" alt="HTML5 Icon" width="900" height="350" >

# %% [markdown]
# <h1 align=center><font size = 5> ESTRUCTURAS DE DATOS - PANDAS DATAFRAMES
# </font></h1>
#
# ---

# %% [markdown]
# ## Tabla de Contenidos
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Series en Pandas</a>
# 2. <a href="#item32">DataFrames en Pandas</a>
# 3. <a href="#item33">Indexación y selección de datos en DataFrames</a>
# 4. <a href="#item34">Limpieza y manipulación de datos</a>
#
# </font>
# </div>
#
# ---

# %% [markdown]
# ## 1. Series en Pandas

# %% [markdown]
# * Es una estructura de datos unidimensional que puede contener datos de cualquier tipo (enteros, flotantes, cadenas, etc.). Es similar a una columna en una tabla o una matriz unidimensional, y se utiliza para representar y manipular conjuntos de datos unidimensionales.
#
# * Una Serie consta de dos componentes principales: los datos y el índice. Los datos representan los valores almacenados en la Serie, mientras que el índice es una etiqueta asociada a cada elemento de los datos que permite identificar y acceder a ellos de manera eficiente.

# %% [markdown]
# ### Creación de Series

# %% [markdown]
# Crear una Serie a partir de una lista:

# %%
import pandas as pd

datos = [10, 20, 30, 40, 50]
serie = pd.Series(datos)
print(serie)

# %% [markdown]
# Crear una Serie a partir de un diccionario:

# %%
datos = {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': 50}
serie = pd.Series(datos)
print(serie)

# %% [markdown]
# Crear una Serie con etiquetas personalizadas:

# %%
datos = [10, 20, 30, 40, 50]
etiquetas = ['A', 'B', 'C', 'D', 'E']

serie = pd.Series(datos, index=etiquetas)
print(serie)

# %% [markdown]
# Crear una Serie a partir de un arreglo de NumPy:

# %%
import numpy as np

arreglo = np.array([10, 20, 30, 40, 50])
serie = pd.Series(arreglo)
print(serie)

# %% [markdown]
# <b> Ejercicio 1 </b>
#
# Crear una Serie con los siguientes datos y mostrarla por pantalla:
#
# * Datos: [25, 10, 15, 30, 20]
# * Índices: ['A', 'B', 'C', 'D', 'E']

# %% [markdown]
# <b> Ejercicio 2 </b>
#
# Crear una Serie con nombres de ciudades como índices y sus respectivas poblaciones como datos.

# %% [markdown]
# ### Indexación y selección de datos

# %%
import pandas as pd

datos = [10, 20, 30, 40, 50]
etiquetas = ['A', 'B', 'C', 'D', 'E']
serie = pd.Series(datos, index = etiquetas)
print(serie)

# %% [markdown]
# Acceder a un elemento específico utilizando una etiqueta:

# %%
print(serie['B'])

# %% [markdown]
# Acceder a varios elementos utilizando una lista de etiquetas:

# %%
print(serie[['A', 'C', 'E']])

# %% [markdown]
# Acceder a elementos utilizando indexación basada en posición:

# %%
print(serie[1])  # Acceder al segundo elemento
print(serie[1:4])  # Acceder a un rango de elementos (exclusivo)

# %% [markdown]
# Acceder a elementos utilizando una condición:

# %%
print(serie[serie > 30])

# %% [markdown]
# <b> Ejercicio 1 </b>
#
# Crear una Serie con nombres de ciudades como índices y sus respectivas poblaciones como datos. Luego, seleccionar las ciudades con población superior a 1 millón.

# %% [markdown]
# <b> Ejercicio 2 </b>
#
# Sobre el mismo ejercicio extraiga el registro de dos ciudades específicas (usted decida cuáles).

# %% [markdown]
# ### Operaciones básicas con Series

# %%
import pandas as pd

serie1 = pd.Series([10, 20, 30, 40, 50])
serie2 = pd.Series([5, 15, 25, 35, 45])

# %% [markdown]
# Sumar dos Series:

# %%
suma = serie1 + serie2
print(suma)

# %% [markdown]
# Restar dos Series:

# %%
resta = serie1 - serie2
print(resta)

# %% [markdown]
# Multiplicar una Serie por un escalar:

# %%
multiplicacion = serie1 * 2
print(multiplicacion)

# %% [markdown]
# Dividir una Serie por otra:

# %%
division = serie1 / serie2
print(division)

# %% [markdown]
# Calcular el cuadrado de una Serie:

# %%
cuadrado = serie1 ** 2
print(cuadrado)

# %% [markdown]
# Calcular la raíz cuadrada de una Serie:

# %%
import numpy as np

raiz_cuadrada = np.sqrt(serie1)
print(raiz_cuadrada)

# %% [markdown]
# Operaciones de tipo str

# %%
datos = ['John', 'Luis', 'Pablo', 'Cesar']
serie = pd.Series(datos)
serie = serie.str.lower()

print(serie)

# %%
datos = ['john', 'luis', 'pablo', 'cesar']
serie = pd.Series(datos)
serie = serie.str.upper()

print(serie)

# %%
datos = ['john', 'luis', 'pablo', 'cesar']
serie = pd.Series(datos)
serie = serie.str.capitalize()

print(serie)

# %% [markdown]
# Algunas operaciones estadísticas

# %%
datos = [2, 4, 2, 5, 1, 3]
serie = pd.Series(datos)

media = serie.mean()
desviacion_estandar = serie.std()

print("Media:", media)
print("Desviación estándar:", desviacion_estandar)

# %% [markdown]
# **Ejercicio 1**
#
# Crear una Serie con números enteros del 1 al 10 como índices y sus respectivos cuadrados como datos.

# %% [markdown]
# **Ejercicio 2**
#
# Crear dos Series con los siguientes datos y luego sumarlas.
#
# > Serie 1: [10, 20, 30, 40, 50]
# >
# > Serie 2: [5, 15, 25, 35, 45]

# %% [markdown]
# **Ejercicio 3**
#
# Crear una Serie a partir de una lista de cadenas y convertir todas las letras a minúsculas.
#
# Datos: ['Manzana', 'Banana', 'Naranja', 'Pera']

# %% [markdown]
# **Ejercicio 4**
#
# Crear una Serie con los siguientes datos y calcular la media y la desviación estándar.
#
# Datos: [15, 22, 18, 25, 20]

# %% [markdown]
# **Ejercicio 5**
#
# Crear una Serie a partir de una lista y reemplazar un valor específico por otro.
#
# Datos: [5, 10, 15, 20, 25]
# Reemplazar el valor 15 por 30.

# %% [markdown]
# **Ejercicio 6**
#
# Crear una Serie con los siguientes datos y mostrar los valores únicos.
#
# Datos: ['manzana', 'pera', 'manzana', 'plátano', 'manzana', 'pera']

# %% [markdown]
# ## 2. DataFrames en Pandas

# %% [markdown]
# * Es una estructura de datos bidimensional que se utiliza para almacenar y manipular datos.
# * Se puede pensar en un DataFrame como una tabla en una base de datos o una hoja de cálculo en Excel.
# * Está compuesto por filas y columnas, donde cada columna puede contener datos de un tipo diferente (enteros, flotantes, cadenas, etc.).
#
# Un DataFrame en Pandas se puede crear de varias formas, pero comúnmente se utiliza para almacenar datos provenientes de archivos CSV, bases de datos o mediante la combinación de otras estructuras de datos, como Series.

# %% [markdown]
# ### 2.1. Creación de DataFrames

# %% [markdown]
# Desde un diccionario de Python

# %%
import pandas as pd

my_dict = {'Nombre' : ['Angelica', 'Marco', 'Diego', 'Hans', 'Dante'],
           'Nota'   : [20, 19, 18, 19, 20]}
data = pd.DataFrame(my_dict)
data
# Out:
#      Nombre  Nota
# 0  Angelica    20
# 1     Marco    19
# 2     Diego    18
# 3      Hans    19
# 4     Dante    20

# %%
import pandas as pd

my_dict = {'Modelo' : ['Reg. Logística', 'Decision Tree', 'XGBoost', 'LGBM', 'SVM'],
           'Gini'   : [20, 30, 40, 45, 28]}
data = pd.DataFrame(my_dict)
data
# Out:
#            Modelo  Gini
# 0  Reg. Logística    20
# 1   Decision Tree    30
# 2         XGBoost    40
# 3            LGBM    45
# 4             SVM    28

# %%
import pandas as pd

data = {'Nombre': ['Juan', 'María', 'Pedro'],
        'Edad': [25, 30, 35],
        'Ciudad': ['Madrid', 'Barcelona', 'Valencia']}

df = pd.DataFrame(data)

df
# Out:
#   Nombre  Edad     Ciudad
# 0   Juan    25     Madrid
# 1  María    30  Barcelona
# 2  Pedro    35   Valencia

# %% [markdown]
# Desde una lista de listas

# %%
import pandas as pd

data = [['Juan', 25, 'Madrid'],
        ['María', 30, 'Barcelona'],
        ['Pedro', 35, 'Valencia']]

df = pd.DataFrame(data, columns=['Name', 'Age', 'City'])
df
# Out:
#     Name  Age       City
# 0   Juan   25     Madrid
# 1  María   30  Barcelona
# 2  Pedro   35   Valencia

# %% [markdown]
# ### 2.2. Carga de datos desde diferentes fuentes (CSV, Excel, SQL, etc.)

# %% [markdown]
# Desde un archivo CSV

# %%
import pandas as pd

df = pd.read_csv('train_titanic.csv')

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# Desde un txt

# %%
import pandas as pd
# , ; | \t
df = pd.read_csv('train_titanic.txt', delimiter = '\t')
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %% [markdown]
# Desde un archivo Excel

# %%
import pandas as pd

# Leer el archivo de Excel en un DataFrame
df = pd.read_excel('train_titanic.xls')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.to_csv("prueba_en_clase.csv", index = False)
pd.read_csv("prueba_en_clase.csv").head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Desde formato parquet

# %%
import pandas as pd

# Leer el archivo Parquet en un DataFrame
df = pd.read_parquet('train_titanic.parquet')

# Imprimir el DataFrame
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500  None        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  None        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  None        S

# %%
# Escribir un archivo en formato parquet
df.to_parquet('train_titanic_guarado.parquet')

# %% [markdown]
# Desde SQL

# %%
import pandas as pd
import sqlite3

# %%
# Establecer la conexión con la base de datos
conn = sqlite3.connect('titanic_train.db')

# Consulta SQL
query = 'SELECT * FROM titanic_train WHERE SEX = "Male"'

# Leer los datos desde la base de datos en un DataFrame
df = pd.read_sql(query, conn)

# Cerrar la conexión con la base de datos
conn.close()

# Imprimir el DataFrame
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500  None        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  None        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  None        S

# %%
import sqlite3

# Establecer la conexión con la base de datos
conn = sqlite3.connect('titanic_train_guardado.db')

# Escribir el DataFrame en un archivo Parquet
df.to_sql('titanic_train_guardado', conn, if_exists='replace', index=False)

# Cerrar la conexión con la base de datos
conn.close()

# %% [markdown]
# Conectar Google Drive a Google Colab

# %%
# Importar la biblioteca google.colab:
from google.colab import drive

# %%
# Montar Google Drive en entorno de Colab
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/train.csv')
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
# Guardar un archivo en drive
df.to_csv('/content/drive/MyDrive/train_prueba.csv')

# %% [markdown]
# ### 2.3. Exploración y manipulación de DataFrames

# %%
pddf = pd.read_csv('sample_data/california_housing_train.csv')
pddf.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# #### Selección de columnas

# %%
pddf.total_rooms
# Out:
# 0        5612.0
# 1        7650.0
# 2         720.0
# 3        1501.0
# 4        1454.0
#           ...
# 16995    2217.0
# 16996    2349.0
# 16997    2677.0
# 16998    2672.0
# 16999    1820.0
# Name: total_rooms, Length: 17000, dtype: float64

# %% [markdown]
# Notación de corchetes

# %%
pddf['total_rooms']  # Selecciona una columna
# Out:
# 0        5612.0
# 1        7650.0
# 2         720.0
# 3        1501.0
# 4        1454.0
#           ...
# 16995    2217.0
# 16996    2349.0
# 16997    2677.0
# 16998    2672.0
# 16999    1820.0
# Name: total_rooms, Length: 17000, dtype: float64

# %%
pddf[['total_rooms']]
# Out:
#        total_rooms
# 0           5612.0
# 1           7650.0
# 2            720.0
# 3           1501.0
# 4           1454.0
# ...            ...
# 16995       2217.0
# 16996       2349.0
# 16997       2677.0
# 16998       2672.0
# 16999       1820.0
#
# [17000 rows x 1 columns]

# %%
pddf[['total_rooms', 'population']]  # Selecciona varias columnas
# Out:
#        total_rooms  population
# 0           5612.0      1015.0
# 1           7650.0      1129.0
# 2            720.0       333.0
# 3           1501.0       515.0
# 4           1454.0       624.0
# ...            ...         ...
# 16995       2217.0       907.0
# 16996       2349.0      1194.0
# 16997       2677.0      1244.0
# 16998       2672.0      1298.0
# 16999       1820.0       806.0
#
# [17000 rows x 2 columns]

# %% [markdown]
# Método loc[]

# %%
pddf.loc[:, 'total_rooms']
# Out:
# 0    5612.0
# 1    7650.0
# 2     720.0
# 3    1501.0
# 4    1454.0
# 5    1387.0
# Name: total_rooms, dtype: float64

# %%
pddf.loc[:, 'total_rooms']  # Selecciona una columna
# Out:
# 0        5612.0
# 1        7650.0
# 2         720.0
# 3        1501.0
# 4        1454.0
#           ...
# 16995    2217.0
# 16996    2349.0
# 16997    2677.0
# 16998    2672.0
# 16999    1820.0
# Name: total_rooms, Length: 17000, dtype: float64

# %%
pddf.loc[5:10, ['total_rooms', 'population']]  # Selecciona varias columnas
# Out:
#     total_rooms  population
# 5        1387.0       671.0
# 6        2907.0      1841.0
# 7         812.0       375.0
# 8        4789.0      3134.0
# 9        1497.0       787.0
# 10       3741.0      2434.0

# %%
pddf.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# <b>Ejercicio </b>
#
# Extraiga la fila de indice 100 hasta el 105 y las columnas total_rooms y median_income

# %%
pddf.loc[pddf.median_income > 2]

# %%
# Filtre los datos con median_income >2

pddfres = pddf.loc[(pddf.median_income > 2) &()]
pddfres.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3    -114.57     33.64                14.0       1501.0           337.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 3       515.0       226.0         3.1917             73400.0
# 5       671.0       239.0         3.3438             74000.0
# 6      1841.0       633.0         2.6768             82400.0
# 8      3134.0      1056.0         2.1782             58400.0
# 9       787.0       271.0         2.1908             48100.0

# %%
pddfres.median_income.min()
# Out:
# 2.0025

# %% [markdown]
# Método iloc[]

# %%
pddf.iloc[:, 0]  # Selecciona una columna por su índice
# Out:
# 0       -114.31
# 1       -114.47
# 2       -114.56
# 3       -114.57
# 4       -114.57
#           ...
# 16995   -124.26
# 16996   -124.27
# 16997   -124.30
# 16998   -124.30
# 16999   -124.35
# Name: longitude, Length: 17000, dtype: float64

# %%
pddf.iloc[:, [0, 1]]  # Selecciona varias columnas por sus índices
# Out:
#        longitude  latitude
# 0        -114.31     34.19
# 1        -114.47     34.40
# 2        -114.56     33.69
# 3        -114.57     33.64
# 4        -114.57     33.57
# ...          ...       ...
# 16995    -124.26     40.58
# 16996    -124.27     40.69
# 16997    -124.30     41.84
# 16998    -124.30     41.80
# 16999    -124.35     40.54
#
# [17000 rows x 2 columns]

# %% [markdown]
# #### Creación de nuevas columnas

# %% [markdown]
# Funciones aplicadas a columnas

# %%
pddf.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
import numpy as np

pddf['nueva_columna'] = np.sqrt(pddf['total_rooms'])
pddf.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  nueva_columna
# 0      1015.0       472.0         1.4936             66900.0      74.913283
# 1      1129.0       463.0         1.8200             80100.0      87.464278
# 2       333.0       117.0         1.6509             85700.0      26.832816
# 3       515.0       226.0         3.1917             73400.0      38.742741
# 4       624.0       262.0         1.9250             65500.0      38.131352

# %% [markdown]
# Condicionales y funciones lambda

# %%
pddf['log_median_income'] = pddf.median_income.apply(lambda x: np.log(x))
pddf.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  nueva_columna  \
# 0      1015.0       472.0         1.4936             66900.0      74.913283
# 1      1129.0       463.0         1.8200             80100.0      87.464278
# 2       333.0       117.0         1.6509             85700.0      26.832816
# 3       515.0       226.0         3.1917             73400.0      38.742741
# 4       624.0       262.0         1.9250             65500.0      38.131352
#
#   nueva_columna2  log_median_income
# 0          Mayor           0.401189
# 1          Mayor           0.598837
# 2          Menor           0.501321
# 3          Mayor           1.160554
# 4          Mayor           0.654926

# %%
1 == True
# Out:
# True

# %%
pddf.columns.tolist()
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value',
#  'nueva_columna',
#  'nueva_columna2',
#  'log_median_income']

# %%
pddf[pddf.columns.tolist()]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  \
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
#        nueva_columna nueva_columna2  log_median_income
# 0          74.913283          Mayor           0.401189
# 1          87.464278          Mayor           0.598837
# 2          26.832816          Menor           0.501321
# 3          38.742741          Mayor           1.160554
# 4          38.131352          Mayor           0.654926
# ...              ...            ...                ...
# 16995      47.085029          Mayor           0.857432
# 16996      48.466483          Mayor           0.923425
# 16997      51.739733          Mayor           1.108992
# 16998      51.691392          Mayor           0.682945
# 16999      42.661458          Mayor           1.103500
#
# [17000 rows x 12 columns]

# %%
pddf.apply(lambda row: row['nueva_columna'] + row['log_median_income'], axis = 1)

# %%
pddf['nueva_columna2'] = pddf['total_rooms'].apply(lambda x: 'Mayor' if x > 1000 else 'Menor')
pddf.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  nueva_columna  \
# 0      1015.0       472.0         1.4936             66900.0      74.913283
# 1      1129.0       463.0         1.8200             80100.0      87.464278
# 2       333.0       117.0         1.6509             85700.0      26.832816
# 3       515.0       226.0         3.1917             73400.0      38.742741
# 4       624.0       262.0         1.9250             65500.0      38.131352
#
#   nueva_columna2
# 0          Mayor
# 1          Mayor
# 2          Menor
# 3          Mayor
# 4          Mayor

# %%
pddf.loc[pddf.nueva_columna2 == 'Menor'].head()
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2     -114.56     33.69                17.0        720.0           174.0
# 7     -114.59     34.83                41.0        812.0           168.0
# 17    -114.65     32.79                21.0         44.0            33.0
# 19    -114.67     33.92                17.0         97.0            24.0
# 21    -114.73     33.43                24.0        796.0           243.0
#
#     population  households  median_income  median_house_value  nueva_columna  \
# 2        333.0       117.0         1.6509             85700.0      26.832816
# 7        375.0       158.0         1.7083             48500.0      28.495614
# 17        64.0        27.0         0.8571             25000.0       6.633250
# 19        29.0        15.0         1.2656             27500.0       9.848858
# 21       227.0       139.0         0.8964             59200.0      28.213472
#
#    nueva_columna2
# 2           Menor
# 7           Menor
# 17          Menor
# 19          Menor
# 21          Menor

# %% [markdown]
# Asignación de un valor constante

# %%
pddf['nueva_columna'] = 1

# %% [markdown]
# ## 3. Indexación y selección de datos en DataFrames

# %% [markdown]
# ### 3.1 Filtrado de filas

# %% [markdown]
# Operadores de comparación

# %%
df_filtrado = pddf[pddf['housing_median_age'] > 30]
df_filtrado.head()
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7     -114.59     34.83                41.0        812.0           168.0
# 8     -114.59     33.61                34.0       4789.0          1175.0
# 9     -114.60     34.83                46.0       1497.0           309.0
# 12    -114.61     34.84                48.0       1291.0           248.0
# 13    -114.61     34.83                31.0       2478.0           464.0
#
#     population  households  median_income  median_house_value  nueva_columna  \
# 7        375.0       158.0         1.7083             48500.0      28.495614
# 8       3134.0      1056.0         2.1782             58400.0      69.202601
# 9        787.0       271.0         2.1908             48100.0      38.691084
# 12       580.0       211.0         2.1571             48600.0      35.930488
# 13      1346.0       479.0         3.2120             70400.0      49.779514
#
#    nueva_columna2  log_median_income
# 7           Menor           0.535499
# 8           Mayor           0.778499
# 9           Mayor           0.784267
# 12          Mayor           0.768765
# 13          Mayor           1.166894

# %% [markdown]
# Operador isin()

# %%
df = pd.read_csv('train_titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
filtro = df['Sex'].isin(['male'])
df_filtrado = df[filtro]
df_filtrado.head()

# %%
df2 = df.loc[df['Sex'].isin(['male', 'female', 'other'])]
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Operador between()

# %%
filtro = df['Age'].between(20, 30)
df_filtrado = df[filtro]
df_filtrado.head()

# %%
df[df['Age'].between(20, 30)].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 8             9         1       3
# 12           13         0       3
# 23           24         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 8       2            347742  11.1333   NaN        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 23      0            113788  35.5000    A6        S

# %%
df[(df['Age'] >= 20) & (df['Age'] <= 30)].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 8             9         1       3
# 12           13         0       3
# 23           24         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 8       2            347742  11.1333   NaN        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 23      0            113788  35.5000    A6        S

# %% [markdown]
# Método query()

# %%
df_filtrado = df.query("Age > 30 and Sex == 'male'")
df_filtrado.head()
# Out:
#     PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 4             5         0       3     Allen, Mr. William Henry  male  35.0
# 6             7         0       1      McCarthy, Mr. Timothy J  male  54.0
# 13           14         0       3  Andersson, Mr. Anders Johan  male  39.0
# 20           21         0       2         Fynney, Mr. Joseph J  male  35.0
# 21           22         1       2        Beesley, Mr. Lawrence  male  34.0
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 4       0      0  373450   8.0500   NaN        S
# 6       0      0   17463  51.8625   E46        S
# 13      1      5  347082  31.2750   NaN        S
# 20      0      0  239865  26.0000   NaN        S
# 21      0      0  248698  13.0000   D56        S

# %% [markdown]
# ### 3.2. Agrupación y agregación

# %% [markdown]
# Operación de agregación

# %%
univariate = df.describe().transpose()
univariate['fill_rate'] = univariate['count']/len(df)
univariate.head()
# Out:
#              count        mean         std   min      25%    50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.500  446.0  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.000    0.0    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.000    3.0    3.0
# Age          714.0   29.699118   14.526497  0.42   20.125   28.0   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.000    0.0    1.0
#
#                max  fill_rate
# PassengerId  891.0   1.000000
# Survived       1.0   1.000000
# Pclass         3.0   1.000000
# Age           80.0   0.801347
# SibSp          8.0   1.000000

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df.groupby('Sex')

# %%
['Age'].mean()

# %%
df.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
df.groupby(['Sex', 'Survived'])['Age'].mean()
# Out:
# Sex     Survived
# female  0           25.046875
#         1           28.847716
# male    0           31.618056
#         1           27.276022
# Name: Age, dtype: float64

# %% [markdown]
# <b> Tarea </b>
#
# 1. En el dataframe de titanic, ¿Cuánto es el ratio de supervivencia de las mujeres y hombre? (sug. use groupby y Survived como promedio).
#
# 2. Indique cel ratio de supervivencia de las mujeres mayores de 20 años y menores de 20 años. sug. use groupby y Survived como promedio).
#
# 3. Cree una columna nueva que calcule la variable Pclass pero con los siguientes cambios:
#
# 1 --> "Primera Clase"
# 2 --> "Segunda Clase"
# 3 --> "Tercera clase"

# %% [markdown]
# ## 4. Limpieza de datos

# %% [markdown]
# ### 4.1. Ordenación

# %%
df_sorted = df.sort_values(by='Age')
df_sorted.head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
df_sorted = df.sort_values(by='Age', ascending = False)
df_sorted.head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %%
df = df.sort_values(by='Age', ascending = False)

# %%
df.sort_values(by='Age', ascending = False, inplace = True)

# %%
df.to_csv('tabla_mod.csv', index = 0)

# %%
df.sort_values(by='Age', ascending = False, inplace=True)
df.head()

# %% [markdown]
# ### 4.2. Eliminación de duplicados:

# %%
df2 = df[['Sex', 'Embarked']]
df2

# %%
df_sin_duplicados = df2.drop_duplicates()
df_sin_duplicados

# %% [markdown]
# Eliminar filas duplicadas basándote en una columna específica:

# %%
df_sin_duplicados = df2.drop_duplicates(subset='Embarked')
df_sin_duplicados

# %% [markdown]
# drop_duplicates() mantiene la primera aparición de una fila duplicada y elimina las siguientes. Sin embargo, puedes cambiar este comportamiento utilizando el argumento keep.

# %%
df_sin_duplicados = df2.drop_duplicates(subset='Embarked', keep='first')
df_sin_duplicados

# %% [markdown]
# ### 4.3. Manipulación de valores faltantes:

# %%
df.isnull().sum()

# %%
df.Age.fillna(df.Age.mean(), inplace = True)
df.isnull().sum()

# %% [markdown]
# ## 5. Operaciones y transformaciones en DataFrames

# %% [markdown]
# ### 5.1. Agregar y eliminar columnas

# %% [markdown]
# Agregar una columna

# %%
df['nueva_columna'] = serie_o_lista

# %% [markdown]
# Eliminar una columna

# %%
df = df.drop('nueva_columna', axis=1)

# %%
del df['nueva_columna']

# %% [markdown]
# ### 5.2. Operaciones aritméticas

# %%
df['suma'] = df['SibSp'] + df['Parch']

# %%
df.head()

# %% [markdown]
# ### 5.3. Combinación de DataFrames

# %% [markdown]
# Concatenación

# %% [markdown]
# La concatenación se utiliza para combinar dos o más DataFrames a lo largo de un eje específico, ya sea por filas o por columnas. El resultado es un nuevo DataFrame que contiene todas las filas o columnas de los DataFrames originales.

# %% [markdown]
# los índices originales se conservan. Si deseas reindexar el DataFrame resultante, puedes utilizar el método reset_index() para restablecer el índice.

# %%
import pandas as pd

# Creamos dos DataFrames de ejemplo
df1 = pd.DataFrame({'A': [1, 2, 3],
                    'B': ['a', 'b', 'c']})

df2 = pd.DataFrame({'A': [4, 5, 6],
                    'B': ['d', 'e', 'f']})

# Concatenamos los DataFrames a lo largo del eje 0 (filas)
df_concatenado = pd.concat([df1, df2], axis=0)

df_concatenado

# %% [markdown]
# merge

# %%
import pandas as pd

# Creamos dos DataFrames de ejemplo
df1 = pd.DataFrame({'ID': [1, 2, 3],
                    'Nombre': ['Juan', 'María', 'Pedro']})

df2 = pd.DataFrame({'ID': [2, 3, 4],
                    'Edad': [25, 30, 35]})

# Realizamos la unión basándonos en la columna 'ID'
df_union = pd.merge(df1, df2, on='ID', how = 'inner')
df_union

# %% [markdown]
# ## 6. Visualización de datos con Pandas

# %% [markdown]
# Visualización con Searborn

# %%
import seaborn as sns

# %%
# Gráfico de distribución
sns.displot(data=df, x='Age')

# %%
# Gráfico de cajas
sns.boxplot(data=df, x='Age')

# %% [markdown]
# ---
#
# # Gracias por completar este laboratorio!
#
# ---
